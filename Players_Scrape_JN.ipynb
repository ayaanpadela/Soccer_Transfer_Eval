# %%
import pandas as pd
import soccerdata as sd
import warnings
warnings.filterwarnings('ignore')

# %%
leagues= ['ENG-Premier League', 'ESP-La Liga', 'FRA-Ligue 1', 'GER-Bundesliga', 'ITA-Serie A']
seasons=["1718"]
print("Initializing scraper")
fbref= sd.FBref(leagues,seasons)
# Out:
# Initializing scraper
# [01/05/26 19:55:15] INFO     Saving cached data to C:\Users\ayaan\soccerdata\data\FBref              ]8;id=514909;file://C:\Users\ayaan\PycharmProjects\3DCalculator\.venv\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=845328;file://C:\Users\ayaan\PycharmProjects\3DCalculator\.venv\Lib\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
stat_types= ["standard","shooting","passing"]
for stat in stat_types:
    print(f"Scraping {stat}")
    df=fbref.read_player_season_stats(stat_type=stat)
    filename= f"data/{stat}.csv"
    df.to_csv(filename)
    print(f"saved to {filename}")
# Out:
# Scraping standard
#                     WARNING  C:\Users\ayaan\PycharmProjects\3DCalculator\.venv\Lib\site-packages\so ]8;id=968489;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=169129;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              ccerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)
# saved to data/standard.csv
# Scraping shooting
# [01/05/26 19:45:00] WARNING  C:\Users\ayaan\PycharmProjects\3DCalculator\.venv\Lib\site-packages\so ]8;id=954638;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=845708;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              ccerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)
# saved to data/shooting.csv
# Scraping passing
# [01/05/26 19:45:41] WARNING  C:\Users\ayaan\PycharmProjects\3DCalculator\.venv\Lib\site-packages\so ]8;id=682886;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=239757;file://C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              ccerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)
# saved to data/passing.csv
